# %%
#Change directory
import os
os.getcwd()
os.chdir("/users/zehongzhuang/Desktop/Database")

# %%
#Import dataset
import pandas as pd
import numpy as np

# %%
names1880=pd.read_csv('babynames/yob1880.txt',names=['names','sex','births'])

# %%
names1880
# Out:
#           names sex  births
# 0          Mary   F    7065
# 1          Anna   F    2604
# 2          Emma   F    2003
# 3     Elizabeth   F    1939
# 4        Minnie   F    1746
# 5      Margaret   F    1578
# 6           Ida   F    1472
# 7         Alice   F    1414
# 8        Bertha   F    1320
# 9         Sarah   F    1288
# 10        Annie   F    1258
# 11        Clara   F    1226
# 12         Ella   F    1156
# 13     Florence   F    1063
# 14         Cora   F    1045
# 15       Martha   F    1040
# 16        Laura   F    1012
# 17       Nellie   F     995
# 18        Grace   F     982
# 19       Carrie   F     949
# 20        Maude   F     858
# 21        Mabel   F     808
# 22       Bessie   F     794
# 23       Jennie   F     793
# 24     Gertrude   F     787
# 25        Julia   F     783
# 26       Hattie   F     769
# 27        Edith   F     768
# 28       Mattie   F     704
# 29         Rose   F     700
# ...         ...  ..     ...
# 1970      Philo   M       5
# ...

# %%
#Sum of the births column by sex 
names1880.groupby('sex').births.sum()
# Out:
# sex
# F     90993
# M    110493
# Name: births, dtype: int64

# %%
#Assemble all of the data into a single DataFrame and further to add a year field
years=range(1880, 2011)

# %%
pieces=[]

# %%
columns=['names','sex','births']

# %%
for year in years:
    path='babynames/yob%s.txt' % year
    frame=pd.read_csv(path, names=columns)
    frame['year']=year
    pieces.append(frame)

# %%
#Concatenate everything into a single DataFrame
names=pd.concat(pieces, ignore_index=True)

# %%
names
# Out:
#              names sex  births  year
# 0             Mary   F    7065  1880
# 1             Anna   F    2604  1880
# 2             Emma   F    2003  1880
# 3        Elizabeth   F    1939  1880
# 4           Minnie   F    1746  1880
# 5         Margaret   F    1578  1880
# 6              Ida   F    1472  1880
# 7            Alice   F    1414  1880
# 8           Bertha   F    1320  1880
# 9            Sarah   F    1288  1880
# 10           Annie   F    1258  1880
# 11           Clara   F    1226  1880
# 12            Ella   F    1156  1880
# 13        Florence   F    1063  1880
# 14            Cora   F    1045  1880
# 15          Martha   F    1040  1880
# 16           Laura   F    1012  1880
# 17          Nellie   F     995  1880
# 18           Grace   F     982  1880
# 19          Carrie   F     949  1880
# 20           Maude   F     858  1880
# 21           Mabel   F     808  1880
# 22          Bessie   F     794  1880
# 23          Jennie   F     793  1880
# ...

# %%
#Aggregating the data at the year and sex level
total_births=names.pivot_table('births', index='year', columns='sex', aggfunc=sum)

# %%
total_births.tail()
# Out:
# sex         F        M
# year
# 2006  1896468  2050234
# 2007  1916888  2069242
# 2008  1883645  2032310
# 2009  1827643  1973359
# 2010  1759010  1898382

# %%
#Insert a column prop with the fraction of babies give each name relative to the total number of births
def add_prop(group):
    #Integer division floors
    births=group.births.astype(float)
    group['prop']=births/births.sum()
    return group

# %%
names=names.groupby(['year','sex']).apply(add_prop)
names
# Out:
#              names sex  births  year      prop
# 0             Mary   F    7065  1880  0.077643
# 1             Anna   F    2604  1880  0.028618
# 2             Emma   F    2003  1880  0.022013
# 3        Elizabeth   F    1939  1880  0.021309
# 4           Minnie   F    1746  1880  0.019188
# 5         Margaret   F    1578  1880  0.017342
# 6              Ida   F    1472  1880  0.016177
# 7            Alice   F    1414  1880  0.015540
# 8           Bertha   F    1320  1880  0.014507
# 9            Sarah   F    1288  1880  0.014155
# 10           Annie   F    1258  1880  0.013825
# 11           Clara   F    1226  1880  0.013474
# 12            Ella   F    1156  1880  0.012704
# 13        Florence   F    1063  1880  0.011682
# 14            Cora   F    1045  1880  0.011484
# 15          Martha   F    1040  1880  0.011429
# 16           Laura   F    1012  1880  0.011122
# 17          Nellie   F     995  1880  0.010935
# 18           Grace   F     982  1880  0.010792
# ...

# %%
#Use np.allclose to check that the group sums are sufficiently close
np.allclose(names.groupby(['year','sex']).prop.sum(),1)
# Out:
# True

# %%
#Extract the top 1000 names for each sex/year combination
def get_top1000(group):
    return group.sort_index(by='births',ascending=False)[:1000]
grouped=names.groupby(['year','sex'])
top1000=grouped.apply(get_top1000)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
pieces=[]
for year, group in names.groupby(['year','sex']):
    pieces.append(group.sort_index(by='births',ascending=False)[:1000])
top1000=pd.concat(pieces, ignore_index=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
top1000
# Out:
#             names sex  births  year      prop
# 0            Mary   F    7065  1880  0.077643
# 1            Anna   F    2604  1880  0.028618
# 2            Emma   F    2003  1880  0.022013
# 3       Elizabeth   F    1939  1880  0.021309
# 4          Minnie   F    1746  1880  0.019188
# 5        Margaret   F    1578  1880  0.017342
# 6             Ida   F    1472  1880  0.016177
# 7           Alice   F    1414  1880  0.015540
# 8          Bertha   F    1320  1880  0.014507
# 9           Sarah   F    1288  1880  0.014155
# 10          Annie   F    1258  1880  0.013825
# 11          Clara   F    1226  1880  0.013474
# 12           Ella   F    1156  1880  0.012704
# 13       Florence   F    1063  1880  0.011682
# 14           Cora   F    1045  1880  0.011484
# 15         Martha   F    1040  1880  0.011429
# 16          Laura   F    1012  1880  0.011122
# 17         Nellie   F     995  1880  0.010935
# 18          Grace   F     982  1880  0.010792
# ...

# %%
#Splitting the Top 1000 names into the boy and girls portions
boys=top1000[top1000.sex=='M']
girls=top1000[top1000.sex=='F']

# %%
#Form a pivot table of the total number of births by year and names
total_births=top1000.pivot_table('births', index='year', columns='names', aggfunc=sum)

# %%
total_births
# Out:
# names   Aaden  Aaliyah  Aarav    Aaron  Aarush   Ab  Abagail  Abb  Abbey  \
# year
# 1880      NaN      NaN    NaN    102.0     NaN  NaN      NaN  NaN    NaN
# 1881      NaN      NaN    NaN     94.0     NaN  NaN      NaN  NaN    NaN
# 1882      NaN      NaN    NaN     85.0     NaN  NaN      NaN  NaN    NaN
# 1883      NaN      NaN    NaN    105.0     NaN  NaN      NaN  NaN    NaN
# 1884      NaN      NaN    NaN     97.0     NaN  NaN      NaN  NaN    NaN
# 1885      NaN      NaN    NaN     88.0     NaN  6.0      NaN  NaN    NaN
# 1886      NaN      NaN    NaN     86.0     NaN  NaN      NaN  NaN    NaN
# 1887      NaN      NaN    NaN     78.0     NaN  NaN      NaN  NaN    NaN
# 1888      NaN      NaN    NaN     90.0     NaN  NaN      NaN  NaN    NaN
# 1889      NaN      NaN    NaN     85.0     NaN  NaN      NaN  NaN    NaN
# 1890      NaN      NaN    NaN     96.0     NaN  NaN      NaN  6.0    NaN
# 1891      NaN      NaN    NaN     69.0     NaN  NaN      NaN  NaN    NaN
# ...

# %%
subset=total_births[['John','Harry','Mary','Marilyn']]

# %%
subset.plot(subplots=True, figsize=(12,10), grid=False, title="Number of births per year")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x12051cf28>,
# ...
#       dtype=object)

# %%
#Aggregate and plot by year and sex
table=top1000.pivot_table('prop', index='year',columns='sex', aggfunc=sum)

# %%
table.plot(title='Sum of table1000.prop.by year and sex', yticks=np.linspace(0,1.2,13),xticks=range(1880, 2020,10))

# %%
df=boys[boys.year==2010]

# %%
df
# Out:
#               names sex  births  year      prop
# 260877        Jacob   M   21875  2010  0.011523
# 260878        Ethan   M   17866  2010  0.009411
# 260879      Michael   M   17133  2010  0.009025
# 260880       Jayden   M   17030  2010  0.008971
# 260881      William   M   16870  2010  0.008887
# 260882    Alexander   M   16634  2010  0.008762
# 260883         Noah   M   16281  2010  0.008576
# 260884       Daniel   M   15679  2010  0.008259
# 260885        Aiden   M   15403  2010  0.008114
# 260886      Anthony   M   15364  2010  0.008093
# 260887       Joshua   M   15238  2010  0.008027
# 260888        Mason   M   14728  2010  0.007758
# 260889  Christopher   M   14135  2010  0.007446
# 260890       Andrew   M   14093  2010  0.007424
# 260891        David   M   14042  2010  0.007397
# 260892      Matthew   M   13954  2010  0.007350
# 260893        Logan   M   13943  2010  0.007345
# 260894       Elijah   M   13735  2010  0.007235
# 260895        James   M   13714  2010  0.007224
# ...

# %%
#Taking the cumulative sum of prop then calling the method searchsorted returns the position
prop_cumsum=df.sort_index(by='prop',ascending=False).prop.cumsum()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)

# %%
prop_cumsum[:10]
# Out:
# 260877    0.011523
# 260878    0.020934
# 260879    0.029959
# 260880    0.038930
# 260881    0.047817
# 260882    0.056579
# 260883    0.065155
# 260884    0.073414
# 260885    0.081528
# 260886    0.089621
# Name: prop, dtype: float64

# %%
prop_cumsum.searchsorted(0.5)
# Out:
# array([116])

# %%
df=boys[boys.year==1990]

# %%
in1900=df.sort_index(by='prop',ascending=False).prop.cumsum()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   """Entry point for launching an IPython kernel.

# %%
in1900.searchsorted(0.5)+1
# Out:
# array([45])

# %%
def get_quantile_count(group, q=0.5):
    group=group.sort_index(by='prop', ascending=False)
    return group.prop.cumsum().searchsorted(q)+1

# %%
diversity=top1000.groupby(['year','sex']).apply(get_quantile_count)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)

# %%
diversity=diversity.unstack('sex')

# %%
diversity.head()
# Out:
# sex      F     M
# year
# 1880  [38]  [14]
# 1881  [38]  [14]
# 1882  [38]  [15]
# 1883  [39]  [15]
# 1884  [39]  [16]

# %%
diversity.plot(title="Number of popular names in top 50%")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-5049dcce250a> in <module>()
# ----> 1 diversity.plot(title="Number of popular names in top 50%")
#
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ...

# %%
#Aggregate all of the births in the full data set by year, sex, and final letter
get_last_letter=lambda x:x[-1]
get_last_letter
# Out:
# <function __main__.<lambda>(x)>

# %%
last_letters=names.names.map(get_last_letter)
last_letters.name='last_letter'

# %%
table=names.pivot_table('births', index=last_letters, columns=['sex','year'],aggfunc=sum)

# %%
#Select out three representative years spanning the history and print the first few rows
subtable=table.reindex(columns=[1910,1960,2010], level='year')

# %%
subtable.head()
# Out:
# sex                 F                            M
# year             1910      1960      2010     1910      1960      2010
# last_letter
# a            108376.0  691247.0  670605.0    977.0    5204.0   28438.0
# b                 NaN     694.0     450.0    411.0    3912.0   38859.0
# c                 5.0      49.0     946.0    482.0   15476.0   23125.0
# d              6750.0    3729.0    2607.0  22111.0  262112.0   44398.0
# e            133569.0  435013.0  313833.0  28655.0  178823.0  129012.0

# %%
subtable.sum()
# Out:
# sex  year
# F    1910     396416.0
#      1960    2022062.0
#      2010    1759010.0
# M    1910     194198.0
#      1960    2132588.0
#      2010    1898382.0
# dtype: float64

# %%
letter_prop=subtable/subtable.sum().astype(float)

# %%
import matplotlib.pyplot as plt
fig, axes=plt.subplots(2,1,figsize=(10,8))
letter_prop['M'].plot(kind='bar',rot=0, ax=axes[0],title='Male')
letter_prop['F'].plot(kind='bar',rot=0,ax=axes[1], title='Female', legend=False)

# %%
#Normalize by year and sex and select a subset of letters for the boy names, finally transposing to make each column a time series
letter_prop=table/table.sum().astype(float)
dny_ts=letter_prop.ix[['d','n','y'],'M'].T
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dny_ts.head()
# Out:
# last_letter         d         n         y
# year
# 1880         0.083055  0.153213  0.075760
# 1881         0.083247  0.153214  0.077451
# 1882         0.085340  0.149560  0.077537
# 1883         0.084066  0.151646  0.079144
# 1884         0.086120  0.149915  0.080405

# %%
dny_ts.plot()

# %%
#Boys names that became girl names
all_names=top1000.names.unique()
mask=np.array(['lesl' in x.lower() for x in all_names])
lesley_like=all_names[mask]
lesley_like
# Out:
# array(['Leslie', 'Lesley', 'Leslee', 'Lesli', 'Lesly'], dtype=object)

# %%
filtered=top1000[top1000.names.isin(lesley_like)]

# %%
filtered.groupby('names').births.sum()
# Out:
# names
# Leslee      1082
# Lesley     35022
# Lesli        929
# Leslie    370429
# Lesly      10067
# Name: births, dtype: int64

# %%
table=filtered.pivot_table('births', index='year',columns='sex', aggfunc='sum')

# %%
table=table.div(table.sum(1),axis=0)

# %%
table.tail()
# Out:
# sex     F   M
# year
# 2006  1.0 NaN
# 2007  1.0 NaN
# 2008  1.0 NaN
# 2009  1.0 NaN
# 2010  1.0 NaN

# %%
table.plot(style={'M': 'k-','F':'k--'})
